# %%
import numpy as np
import matplotlib.pyplot as plt
from group_size_comparison_experiment import *
# %run constants.py

# %%
# group size 2
algs = ['svm', 'logistic regression', 'multilayer perceptron']
# data to plot
n_groups = 3
thund = [alg_svm2_aver_normal, alg_lr2_aver_normal, alg_nn2_aver_normal]
baseline = [alg_svm2_aver_baseline, alg_lr2_aver_baseline, alg_nn2_aver_baseline]
centr = [alg_svm2_aver_real, alg_lr2_aver_real, alg_nn2_aver_real]

# create plot
fig, ax = plt.subplots(figsize=(12, 10))
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.8
ax.set_ylim(ymin=0.7)
ax.set_ylim(ymax=0.85)
rects1 = plt.bar(index, thund, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Thunderdome')
 
rects2 = plt.bar(index + bar_width, baseline, bar_width,
                 alpha=opacity,
                 color='g',
                 label='Baseline')

rects2 = plt.bar(index + 2*bar_width, centr, bar_width,
                 alpha=opacity,
                 color='r',
                 label='Centralized')
 
plt.xlabel('Algorithm')
plt.ylabel('AUC')
plt.title('AUC for GROUP SIZE 2 (5000000 samples, 1000 models)')
plt.xticks(index + bar_width, algs)
plt.legend(fontsize = 'xx-large')
 
plt.tight_layout()
plt.show()

# %%
# group size 5
algs = ['svm', 'logistic regression', 'multilayer perceptron']
# data to plot
n_groups = 3
thund = [alg_svm5_aver_normal, alg_lr5_aver_normal, alg_nn5_aver_normal]
baseline = [alg_svm5_aver_baseline, alg_lr5_aver_baseline, alg_nn5_aver_baseline]
centr = [alg_svm5_aver_real, alg_lr5_aver_real, alg_nn5_aver_real]

# create plot
fig, ax = plt.subplots(figsize=(12, 10))
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.8
ax.set_ylim(ymin=0.7)
ax.set_ylim(ymax=0.85)
rects1 = plt.bar(index, thund, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Thunderdome')
 
rects2 = plt.bar(index + bar_width, baseline, bar_width,
                 alpha=opacity,
                 color='g',
                 label='Baseline')

rects2 = plt.bar(index + 2*bar_width, centr, bar_width,
                 alpha=opacity,
                 color='r',
                 label='Centralized')
 
plt.xlabel('Algorithm')
plt.ylabel('AUC')
plt.title('AUC for GROUP SIZE 5 (5000000 samples, 1000 models)')
plt.xticks(index + bar_width, algs)
plt.legend(fontsize = 'xx-large')
 
plt.tight_layout()
plt.show()

# %%
# group size 10
algs = ['svm', 'logistic regression', 'multilayer perceptron']
# data to plot
n_groups = 3
thund = [alg_svm10_aver_normal, alg_lr10_aver_normal, alg_nn10_aver_normal]
baseline = [alg_svm10_aver_baseline, alg_lr10_aver_baseline, alg_nn10_aver_baseline]
centr = [alg_svm10_aver_real, alg_lr10_aver_real, alg_nn10_aver_real]

# create plot
fig, ax = plt.subplots(figsize=(12, 10))
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.8
ax.set_ylim(ymin=0.7)
ax.set_ylim(ymax=0.85)
rects1 = plt.bar(index, thund, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Thunderdome')
 
rects2 = plt.bar(index + bar_width, baseline, bar_width,
                 alpha=opacity,
                 color='g',
                 label='Baseline')

rects2 = plt.bar(index + 2*bar_width, centr, bar_width,
                 alpha=opacity,
                 color='r',
                 label='Centralized')
 
plt.xlabel('Algorithm')
plt.ylabel('AUC')
plt.title('AUC for GROUP SIZE 10 (5000000 samples, 1000 models)')
plt.xticks(index + bar_width, algs)
plt.legend(fontsize = 'xx-large')
 
plt.tight_layout()
plt.show()

# %%
# group size 50
algs = ['svm', 'logistic regression', 'multilayer perceptron']
# data to plot
n_groups = 3
thund = [alg_svm50_aver_normal, alg_lr50_aver_normal, alg_nn50_aver_normal]
baseline = [alg_svm50_aver_baseline, alg_lr50_aver_baseline, alg_nn50_aver_baseline]
centr = [alg_svm50_aver_real, alg_lr50_aver_real, alg_nn50_aver_real]

# create plot
fig, ax = plt.subplots(figsize=(12, 10))
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.8
ax.set_ylim(ymin=0.7)
ax.set_ylim(ymax=0.85)
rects1 = plt.bar(index, thund, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Thunderdome')
 
rects2 = plt.bar(index + bar_width, baseline, bar_width,
                 alpha=opacity,
                 color='g',
                 label='Baseline')

rects2 = plt.bar(index + 2*bar_width, centr, bar_width,
                 alpha=opacity,
                 color='r',
                 label='Centralized')
 
plt.xlabel('Algorithm')
plt.ylabel('AUC')
plt.title('AUC for GROUP SIZE 50 (5000000 samples, 1000 models)')
plt.xticks(index + bar_width, algs)
plt.legend(fontsize = 'xx-large')
 
plt.tight_layout()
plt.show()

# %%
# group size 100
algs = ['svm', 'logistic regression', 'multilayer perceptron']
# data to plot
n_groups = 3
thund = [alg_svm100_aver_normal, alg_lr100_aver_normal, alg_nn100_aver_normal]
baseline = [alg_svm100_aver_baseline, alg_lr100_aver_baseline, alg_nn100_aver_baseline]
centr = [alg_svm100_aver_real, alg_lr100_aver_real, alg_nn100_aver_real]

# create plot
fig, ax = plt.subplots(figsize=(12, 10))
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.8
ax.set_ylim(ymin=0.7)
ax.set_ylim(ymax=0.85)
rects1 = plt.bar(index, thund, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Thunderdome')
 
rects2 = plt.bar(index + bar_width, baseline, bar_width,
                 alpha=opacity,
                 color='g',
                 label='Baseline')

rects2 = plt.bar(index + 2*bar_width, centr, bar_width,
                 alpha=opacity,
                 color='r',
                 label='Centralized')
 
plt.xlabel('Algorithm')
plt.ylabel('AUC')
plt.title('AUC for GROUP SIZE 100 (5000000 samples, 1000 models)')
plt.xticks(index + bar_width, algs)
plt.legend(fontsize = 'xx-large')
 
plt.tight_layout()
plt.show()
