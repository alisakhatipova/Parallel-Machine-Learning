# %%
import numpy as np
import matplotlib.pyplot as plt
# %run constants.py

# %%
algs = ['svm', 'lr', 'nn']
# data to plot
n_groups = 3
res = [0.82, 0.8100, 0.85]
baseline = [0.827, 0.8116, 0.85]
simple = [0.9, 0.96, 0.94]

# create plot
fig, ax = plt.subplots(figsize=(12, 10))
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.8
ax.set_ylim(ymin=0.7)
rects1 = plt.bar(index, res, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Thunderdome')
 
rects2 = plt.bar(index + bar_width, baseline, bar_width,
                 alpha=opacity,
                 color='g',
                 label='Baseline')

rects2 = plt.bar(index + 2*bar_width, simple, bar_width,
                 alpha=opacity,
                 color='r',
                 label='Centralized')
 
plt.xlabel('Algorithm')
plt.ylabel('AUC')
plt.title('AUC for different algorithms (30 models)')
plt.xticks(index + bar_width, algs)
plt.legend()
 
plt.tight_layout()
plt.show()

# %%
algs = ['svm', 'lr', 'nn']
# data to plot
n_groups = 3
res = [0.7543, 0.748, 0.749]
baseline = [0.75943, 0.755, 0.749]
simple = [0.77, 0.775, 0.775]

# create plot
fig, ax = plt.subplots(figsize=(12, 10))
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.8
ax.set_ylim(ymin=0.7)
ax.set_ylim(ymax=0.8)
rects1 = plt.bar(index, res, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Thunderdome')
 
rects2 = plt.bar(index + bar_width, baseline, bar_width,
                 alpha=opacity,
                 color='g',
                 label='Baseline')

rects2 = plt.bar(index + 2*bar_width, simple, bar_width,
                 alpha=opacity,
                 color='r',
                 label='Centralized')
 
plt.xlabel('Algorithm')
plt.ylabel('AUC')
plt.title('AUC for different algorithms (500 models)')
plt.xticks(index + bar_width, algs)
plt.legend()
 
plt.tight_layout()
plt.show()

# %%
simple
# Out:
# [0.9208165997322624,
#  0.9208165997322624,
#  0.9208165997322624,
#  0.9208165997322624,
#  0.9208165997322624]
